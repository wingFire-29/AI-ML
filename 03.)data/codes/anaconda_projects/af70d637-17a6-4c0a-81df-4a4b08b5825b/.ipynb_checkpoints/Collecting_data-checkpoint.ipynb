# %%
import requests

# %%
url="https://stephen-king-api.onrender.com/api/books"
response=requests.get(url)

# %%
response # response code 200==everything worked successfully
# Out:
# <Response [200]>

# %%
json_data=response.json()

# %%
import pandas as pd
df=pd.json_normalize(json_data["data"])
df=df[['id','Title','Year','ISBN']]

# %%
df.sample(5)
# Out:
#     id                  Title  Year               ISBN
# 10  11        The Running Man  1982  978-0-451-11508-9
# 37  38            Black House  2001  978-0-375-50439-6
# 14  15  Cycle of the Werewolf  1983  978-0-960-38282-8
# 4    5              The Stand  1978  978-0-385-12168-2
# 55  56           End of Watch  2016  978-1-501-12974-2
