# %%
import requests

# %%
URL="https://www.scrapethissite.com/pages/simple/"

# %%
res=requests.get(URL)

# %%
print(res.status_code)
# Out:
# 200

# %%
if res.status_code == 200:
    print(res.headers)
with open("Scraped_data/data.html", "w", encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sat, 14 Mar 2026 17:58:26 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=gZWQSkzbU2g%2BYpaTVOfr97KcRqMEDAt%2BPUNrrqJ3oI0%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1773511106"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=gZWQSkzbU2g%2BYpaTVOfr97KcRqMEDAt%2BPUNrrqJ3oI0%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1773511106"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'br', 'CF-RAY': '9dc52a9bcf2695fd-DEL', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Beatiful soup
from bs4 import BeautifulSoup

with open("Scraped_data/data.html","r") as f:
    html_content=f.read()
soup=BeautifulSoup(html_content,"lxml")

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------- ----------- 2.9/4.1 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 16.8 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\parag\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
#Beatiful soup
from bs4 import BeautifulSoup

with open("Scraped_data/data.html","r") as f:
    html_content=f.read()
soup=BeautifulSoup(html_content,"lxml")

# %%
all_h3=soup.find_all("h3")
all_countries=[]

for h3 in all_h3:
    name=h3.get_text(strip=True)
    # print(h3.find_parent("div")["class"])
    population=h3.find_next("div").select("span.country-population")[0].get_text(strip=True)
    all_countries.append([name,population])

# %%
import pandas as pd
df=pd.DataFrame(all_countries,columns=["Name","Population"])

# %%
# Activity1
import requests
URL1="https://quotes.toscrape.com/"
res=requests.get(URL1)

# %%
print(res.status_code)
# Out:
# 200

# %%
if res.status_code == 200:
    print(res.headers)
# Out:
# {'Date': 'Sat, 14 Mar 2026 19:11:22 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '11064', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=0; includeSubDomains; preload'}

# %%
with open("Scraped_data/Quotes.html","w", encoding="utf-8") as f:
    f.write(res.text)

# %%
from bs4 import BeautifulSoup
with open("Scraped_data/Quotes.html","r", encoding="utf-8") as f:
    Quotes=f.read()
soup=BeautifulSoup(Quotes,"lxml")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[21], line 4
#       2 with open("Scraped_data/Quotes.html","r", encoding="utf-8") as f:
#       3     Quotes=f.read()
# ----> 4 soup=BeautifulSoup(Quotes,"lxml")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\bs4\__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
# ...
